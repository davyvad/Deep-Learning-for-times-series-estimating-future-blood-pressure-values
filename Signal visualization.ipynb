# %%
import math
# Load the Pandas libraries with alias 'pd' 
import pandas as pd 
# Read data from file 'filename.csv' 
# (in the same directory that your python process is based)
# Control delimiters, rows, column names with read_csv (see later) 
#data = pd.read_csv("911-7927-MDC_PRESS_BLD_ART_ABP-125.csv", header=None) 
data = pd.read_csv("2677398-3033-MDC_PRESS_BLD_ART_ABP-125.csv", header=None) 
# Preview the first 5 lines of the loaded data 
data.head()
# Out:
#               0     1
# 0  1.486151e+09  2030
# 1  1.486151e+09  2017
# 2  1.486151e+09  1995
# 3  1.486151e+09  1971
# 4  1.486151e+09  1947

# %%
data.iloc[::500, :]
# Out:
#                    0     1
# 0       1.486151e+09  2030
# 500     1.486151e+09  2005
# 1000    1.486151e+09  2005
# 1500    1.486151e+09  1996
# 2000    1.486151e+09  2011
# ...              ...   ...
# 286500  1.486153e+09  2083
# 287000  1.486153e+09  2093
# 287500  1.486153e+09  2090
# 288000  1.486153e+09  2072
# 288500  1.486153e+09  2058
#
# [578 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

df = data.iloc[::100, :]
df = data[0:500]
# a scatter plot comparing num_children and num_pets
df.plot(kind='scatter',x=0,y=1,color='red')
plt.show()

# %% [markdown]
# # I don't understand what did you try to do with <df = data.iloc[::100, :]>??

# %%
# ploting ~10 seconds of blood pressure
sampleRate = 125 # hz
nSamples = 5*sampleRate
tVec = data.values[:nSamples, 0]
bp = (data.values[:nSamples, 1])*0.0625-40 # this is a formula I know from the CSV values to mmHg
plt.figure(figsize=(16,8))
plt.plot(tVec, bp)
plt.xlabel('sec')
plt.ylabel('mmHg')
plt.show()

# %%
data.head()


df = data.iloc[0:1000]
#print(df)

df['difference'] = df[1].diff(-25)
df['difference'] = abs(df['difference'])*100/df[1]
df.plot(kind='scatter',x='difference',y=1,color='red')


print(df)

#print(df)
#df.plot(kind='scatter', x=2, y=1, color='red')
# Out:
#                 0     1  difference
# 0    1.486151e+09  2030   14.482759
# 1    1.486151e+09  2017   14.229053
# 2    1.486151e+09  1995   13.433584
# 3    1.486151e+09  1971   12.075089
# 4    1.486151e+09  1947    9.501798
# ..            ...   ...         ...
# 995  1.486151e+09  1946         NaN
# 996  1.486151e+09  1955         NaN
# 997  1.486151e+09  1972         NaN
# 998  1.486151e+09  1991         NaN
# 999  1.486151e+09  2003         NaN
#
# [1000 rows x 3 columns]
# /media/ront/Files/anaconda3/envs/pytorchDenoising/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# ...
